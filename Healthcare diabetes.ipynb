# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv("C:\\Users\\harsha k\\Desktop\\Healthcare - Diabetes\\health care diabetes.csv")
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data['Glucose'].value_counts()
# Out:
# 99     17
# 100    17
# 111    14
# 129    14
# 125    14
#        ..
# 191     1
# 177     1
# 44      1
# 62      1
# 190     1
# Name: Glucose, Length: 136, dtype: int64

# %%
data['Glucose'].plot(kind='hist',figsize=(7,4))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# We can see from histogram most of observation have Glucose level between 100 and 120.

# %% [markdown]
# A value of zero does not make sense and thus indicates missing value. Replacing zero by their mean values.

# %%
data['BloodPressure'].unique()
# Out:
# array([ 72,  66,  64,  40,  74,  50,   0,  70,  96,  92,  80,  60,  84,
#         30,  88,  90,  94,  76,  82,  75,  58,  78,  68, 110,  56,  62,
#         85,  86,  48,  44,  65, 108,  55, 122,  54,  52,  98, 104,  95,
#         46, 102, 100,  61,  24,  38, 106, 114], dtype=int64)

# %%
data['BloodPressure'].plot(kind='hist',figsize=(7,4))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# We can see from histogram most of observation have Blood Pressure between 60 and 80.

# %%
data['SkinThickness'].unique()
# Out:
# array([35, 29,  0, 23, 32, 45, 19, 47, 38, 30, 41, 33, 26, 15, 36, 11, 31,
#        37, 42, 25, 18, 24, 39, 27, 21, 34, 10, 60, 13, 20, 22, 28, 54, 40,
#        51, 56, 14, 17, 50, 44, 12, 46, 16,  7, 52, 43, 48,  8, 49, 63, 99],
#       dtype=int64)

# %%
data['SkinThickness'].value_counts()
# Out:
# 0     227
# 32     31
# 30     27
# 27     23
# 23     22
# 33     20
# 28     20
# 18     20
# 31     19
# 19     18
# 39     18
# 29     17
# 40     16
# 25     16
# 26     16
# 22     16
# 37     16
# 41     15
# 35     15
# 36     14
# 15     14
# 17     14
# 20     13
# 24     12
# 42     11
# 13     11
# 21     10
# 46      8
# 34      8
# 12      7
# 38      7
# 11      6
# 43      6
# 16      6
# 45      6
# 14      6
# 44      5
# 10      5
# 48      4
# 47      4
# 49      3
# 50      3
# 8       2
# 7       2
# 52      2
# 54      2
# 63      1
# 60      1
# 56      1
# 51      1
# 99      1
# Name: SkinThickness, dtype: int64

# %%
data['SkinThickness']=data['SkinThickness'].replace(0,data['SkinThickness'].mean())

# %%
data['SkinThickness'].plot(kind='hist',figsize=(7,4))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# We can see from histogram most of observation have SkinThickness between 20 and 25.

# %%
 data['Insulin'].value_counts()
# Out:
# 0      374
# 105     11
# 130      9
# 140      9
# 120      8
#       ...
# 73       1
# 171      1
# 255      1
# 52       1
# 112      1
# Name: Insulin, Length: 186, dtype: int64

# %%
 data['Insulin']= data['Insulin'].replace(0,  data['Insulin'].mean())

# %%
 data['Insulin'].plot(kind='hist',figsize=(7,4))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# We can see from histogram most of observation have insulin between 1

# %%
data['BMI'].value_counts()
# Out:
# 32.0    13
# 31.6    12
# 31.2    12
# 0.0     11
# 32.4    10
#         ..
# 36.7     1
# 41.8     1
# 42.6     1
# 42.8     1
# 46.3     1
# Name: BMI, Length: 248, dtype: int64

# %%
data['BMI']=data['BMI'].replace(0,data['BMI'].mean())

# %%
data['BMI'].plot(kind='hist',figsize=(7,4))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# We can see from histogram most of observation have BMI between 28 to 32

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6      148             72      35.000000   79.799479  33.6
# 1              1       85             66      29.000000   79.799479  26.6
# 2              8      183             64      20.536458   79.799479  23.3
# 3              1       89             66      23.000000   94.000000  28.1
# 4              0      137             40      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10      101             76      48.000000  180.000000  32.9
# 764            2      122             70      27.000000   79.799479  36.8
# 765            5      121             72      23.000000  112.000000  26.2
# 766            1      126             60      20.536458   79.799479  30.1
# 767            1       93             70      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
sns.pairplot(data)

# %% [markdown]
# We can see from scatter plot that there is no strong multicolinearity among features.Skin thickness and BMI, Pregnancies and age it looks like there is small chance of positive correlation.Will explore more when analyzing correlation

# %% [markdown]
# # Correlation Analysis

# %%
data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282       0.013376
# Glucose                      0.129459  1.000000       0.152590       0.145378
# BloodPressure                0.141282  0.152590       1.000000       0.180890
# SkinThickness                0.013376  0.145378       0.180890       1.000000
# Insulin                     -0.018082  0.390835       0.074858       0.240361
# BMI                          0.021546  0.218814       0.184252       0.535703
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.154961
# Age                          0.544341  0.263514       0.239528       0.026423
# Outcome                      0.221898  0.466581       0.065068       0.175026
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.018082  0.021546                 -0.033523
# ...

# %%
plt.figure(dpi=80)
sns.heatmap(data.corr(),cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6      148             72      35.000000   79.799479  33.6
# 1              1       85             66      29.000000   79.799479  26.6
# 2              8      183             64      20.536458   79.799479  23.3
# 3              1       89             66      23.000000   94.000000  28.1
# 4              0      137             40      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10      101             76      48.000000  180.000000  32.9
# 764            2      122             70      27.000000   79.799479  36.8
# 765            5      121             72      23.000000  112.000000  26.2
# 766            1      126             60      20.536458   79.799479  30.1
# 767            1       93             70      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
x=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,random_state=40,test_size=0.2)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (614, 8)
# (154, 8)
# (614,)
# (154,)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors=25) 
#Using 25 Neighbors just as thumb rule sqrt of observation
knn_model.fit(x_train,y_train)
knn_pred=knn_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score,roc_curve,auc

# %%
print("Accuracy Score :",accuracy_score(knn_pred,y_test))
print("Conusion Matrix \n:",confusion_matrix(knn_pred,y_test))
print("classification_report \n:",classification_report(knn_pred,y_test))
# Out:
# Accuracy Score : 0.7597402597402597
# Conusion Matrix
# : [[89 31]
#  [ 6 28]]
# classification_report
# :               precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83       120
#            1       0.47      0.82      0.60        34
#
#     accuracy                           0.76       154
#    macro avg       0.71      0.78      0.72       154
# weighted avg       0.83      0.76      0.78       154

# %%
probs=knn_model.predict_proba(x_test)

# %%
probs=probs[:,1]

# %%
roc_auc_score(y_test,probs)
# Out:
# 0.8188224799286351

# %%
fpr,tpr,thresholds=roc_curve(y_test,probs)
roc_auc_knn=auc(fpr,tpr)

# %%
plt.figure(dpi=80)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_knn)
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
# C:\Users\harsha k\AppData\Local\Temp\ipykernel_26220\2109408960.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(fpr,fpr,'r--',color='red')

# %%
from sklearn.svm import SVC
svc_model_linear = SVC(kernel='linear',random_state=0,probability=True,C=0.01) 
svc_model_linear.fit(x_train,y_train)
svc_pred=svc_model_linear.predict(x_test)

# %%
print("Accuracy Score :",accuracy_score(svc_pred,y_test))
print("Conusion Matrix \n:",confusion_matrix(svc_pred,y_test))
print("classification_report \n:",classification_report(svc_pred,y_test))
# Out:
# Accuracy Score : 0.7597402597402597
# Conusion Matrix
# : [[85 27]
#  [10 32]]
# classification_report
# :               precision    recall  f1-score   support
#
#            0       0.89      0.76      0.82       112
#            1       0.54      0.76      0.63        42
#
#     accuracy                           0.76       154
#    macro avg       0.72      0.76      0.73       154
# weighted avg       0.80      0.76      0.77       154

# %%
probs_svc=svc_model_linear .predict_proba(x_test)

# %%
probs_svc=probs_svc[:,1]

# %%
roc_auc_score(y_test,probs_svc)
# Out:
# 0.8308652988403211

# %%
fpr,tpr,thresholds=roc_curve(y_test,probs_svc)
roc_auc_svc=auc(fpr,tpr)

# %%
plt.figure(dpi=80)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_svc)
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
# C:\Users\harsha k\AppData\Local\Temp\ipykernel_26220\3617412791.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(fpr,fpr,'r--',color='red')

# %%
from sklearn.linear_model import LogisticRegression
lr_model = LogisticRegression(C=0.01) 
lr_model.fit(x_train,y_train)
lr_pred=lr_model.predict(x_test)
print("Accuracy Score :",accuracy_score(lr_pred,y_test))
print("Conusion Matrix \n:",confusion_matrix(lr_pred,y_test))
print("classification_report \n:",classification_report(lr_pred,y_test))
# Out:
# Accuracy Score : 0.7727272727272727
# Conusion Matrix
# : [[86 26]
#  [ 9 33]]
# classification_report
# :               precision    recall  f1-score   support
#
#            0       0.91      0.77      0.83       112
#            1       0.56      0.79      0.65        42
#
#     accuracy                           0.77       154
#    macro avg       0.73      0.78      0.74       154
# weighted avg       0.81      0.77      0.78       154
# C:\Users\harsha k\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
probs_lr=lr_model.predict_proba(x_test)
probs_lr=probs_lr[:,1]
roc_auc_score(y_test,probs_lr)
# Out:
# 0.8394290811775201

# %%
fpr,tpr,thresholds=roc_curve(y_test,probs_lr)
roc_auc_lr=auc(fpr,tpr)

# %%
plt.figure(dpi=80)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_lr)
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
# C:\Users\harsha k\AppData\Local\Temp\ipykernel_26220\1051094460.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(fpr,fpr,'r--',color='red')

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=1000,random_state=0)
rf_model.fit(x_train,y_train)
rf_pred=rf_model.predict(x_test)
print("Accuracy Score :",accuracy_score(rf_pred,y_test))
print("Conusion Matrix \n:",confusion_matrix(rf_pred,y_test))
print("classification_report \n:",classification_report(rf_pred,y_test))
# Out:
# Accuracy Score : 0.7662337662337663
# Conusion Matrix
# : [[85 26]
#  [10 33]]
# classification_report
# :               precision    recall  f1-score   support
#
#            0       0.89      0.77      0.83       111
#            1       0.56      0.77      0.65        43
#
#     accuracy                           0.77       154
#    macro avg       0.73      0.77      0.74       154
# weighted avg       0.80      0.77      0.78       154

# %%
probs_rf=rf_model.predict_proba(x_test)
probs_rf=probs_rf[:,1]
roc_auc_score(y_test,probs_rf)
# Out:
# 0.8264049955396967

# %%
fpr,tpr,thresholds=roc_curve(y_test,probs_rf)
roc_auc_rf=auc(fpr,tpr)

# %%
plt.figure(dpi=80)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_rf)
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
# C:\Users\harsha k\AppData\Local\Temp\ipykernel_26220\1063062018.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(fpr,fpr,'r--',color='red')
